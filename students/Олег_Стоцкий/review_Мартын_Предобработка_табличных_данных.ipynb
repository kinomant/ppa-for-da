# %% [markdown]
# Для предобработки табличных данных воспользуемся библиотекой panddas

# %% [markdown]
# Требуется импортировать библиотеку

# %%
import pandas as pd

# %% [markdown]
# В нашем уроке воспользуемся тестовыми данными

# %%
df = pd.DataFrame([[18, 160, "1"], [19, 170, "2"], [20, 175, None], [21, 170, "4"], [22, 160, "5x"]])
df
# Out:
#     0    1     2
# 0  18  160     1
# 1  19  170     2
# 2  20  175  None
# 3  21  170     4
# 4  22  160    5x

# %% [markdown]
# Переименуем колонки, чтобы в дальнейшем с ними было удобнее работать

# %%
col_name = ['age', "height", "num"]
df.set_axis(col_name, axis = 'columns', inplace = True)

# %% [markdown]
# Для удаления строк у которых отсутствует хотя бы одно значение воспользуемся методом dropna. Стоит обратить внимание что вызов данного метода никак не изменяет на df поэтому здесь мы увидим результат, но не сохраним его

# %%
df.dropna()
# Out:
#    age  height num
# 0   18     160   1
# 1   19     170   2
# 3   21     170   4
# 4   22     160  5x

# %% [markdown]
# Если требуется удалить строки в которых отсутствуют конкретные значения, можно воспользоваться аргументом subset

# %%
df.dropna(subset=['height'], inplace=True)
df
# Out:
#    age  height   num
# 0   18     160     1
# 1   19     170     2
# 2   20     175  None
# 3   21     170     4
# 4   22     160    5x

# %% [markdown]
# Рассмотрим тип колонки num. Как видно ее тип object, так как существуют строки которые невозможно привести к числовому типу

# %%
df['num']
# Out:
# 0       1
# 1       2
# 2    None
# 3       4
# 4      5x
# Name: num, dtype: object

# %% [markdown]
# Чтобы поменять тип воспользуемся методом astype

# %%
df['num'].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-5a2e14efa1cb> in <module>()
# ----> 1 df['num'].astype('int64')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %% [markdown]
# Получим ошибку. Для того чтобы исправить ее, требуется удалить None и не числовые строки из выборки.

# %%
df = df[df['num'].isnull() != True]
df
# Out:
#    age  height num
# 0   18     160   1
# 1   19     170   2
# 3   21     170   4
# 4   22     160  5x

# %%
df = df[pd.to_numeric(df['num'], errors='coerce').notnull()]
df
# Out:
#    age  height num
# 0   18     160   1
# 1   19     170   2
# 3   21     170   4

# %%
df = df.astype({'num': 'int32'})
df
# Out:
#    age  height  num
# 0   18     160    1
# 1   19     170    2
# 3   21     170    4

# %% [markdown]
# Также если в колонке с числовыми значениями пропущено какое-то значение, одним из стандартных приемов является заменение null на среднее по этой колонке:

# %%
df.iloc[0] = [18, None, 1]
df
# Out:
#    age  height  num
# 0   18     NaN    1
# 1   19   170.0    2
# 3   21   170.0    4

# %%
df.fillna(df.mean())
# Out:
#    age  height  num
# 0   18   170.0    1
# 1   19   170.0    2
# 3   21   170.0    4

# %% [markdown]
# Ревью Стоцкий Олег: добавил пункт про заполнение пропущенных значений средними
