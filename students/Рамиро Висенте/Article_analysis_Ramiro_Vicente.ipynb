# %% [markdown]
# # **Анализ документов: Automated machine learning: Review of the state-of-the-art andopportunities for healthcare**
# В этом документе анализируются различные случаи использования машинного обучения в области медицины, которые в настоящее время выполняются:

# %% [markdown]
# https://www.sciencedirect.com/science/article/pii/S0933365719310437

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Кроме того, поскольку это общая статья, в которой собрана информация по различным темам, в самой статье даются рекомендации по различным способам использования методов обучения AMchine, таблица добавлена ​​ниже:

# %% [markdown]
# ![image.png](data:image/png;base64,...)
